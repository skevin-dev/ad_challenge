# %%
import pandas as pd
import psycopg2

# %%
# create connection 
conn = psycopg2.connect(
   database="airflow", user='airflow', password='airflow', host='localhost', port= '5432'
)

# %%
#Setting auto commit false
conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

# %%
#Retrieving data
cursor.execute('''SELECT * from all_data''')

# %%
#Fetching data from the table
result = cursor.fetchall();
print(len(result))
# Out:
# 423812

# %%
df = pd.DataFrame(result)

# %%
df
# Out:
#              0                                                  1   \
# 0       qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 1       qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 2       qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 3       qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 4       qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# ...         ...                                                ...
# 423807  qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 423808  qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 423809  qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 423810  qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 423811  qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
#
#                       2                                                  3   \
# 0       23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 1       23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 2       23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 3       23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 4       23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# ...                  ...                                                ...
# 423807  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 423808  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 423809  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 423810  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 423811  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
#
#                                                        4   \
# 0       Brand Awareness\nProduct Awareness\nConsiderat...
# 1       Brand Awareness\nProduct Awareness\nConsiderat...
# 2       Brand Awareness\nProduct Awareness\nConsiderat...
# 3       Brand Awareness\nProduct Awareness\nConsiderat...
# 4       Brand Awareness\nProduct Awareness\nConsiderat...
# ...                                                   ...
# 423807  Brand Awareness\nProduct Awareness\nConsiderat...
# 423808  Brand Awareness\nProduct Awareness\nConsiderat...
# 423809  Brand Awareness\nProduct Awareness\nConsiderat...
# 423810  Brand Awareness\nProduct Awareness\nConsiderat...
# 423811  Brand Awareness\nProduct Awareness\nConsiderat...
#
#                                            5   \
# 0       CTR\nConversion Rate\nEngagement Rate
# 1       CTR\nConversion Rate\nEngagement Rate
# 2       CTR\nConversion Rate\nEngagement Rate
# 3       CTR\nConversion Rate\nEngagement Rate
# 4       CTR\nConversion Rate\nEngagement Rate
# ...                                       ...
# 423807  CTR\nConversion Rate\nEngagement Rate
# 423808  CTR\nConversion Rate\nEngagement Rate
# 423809  CTR\nConversion Rate\nEngagement Rate
# 423810  CTR\nConversion Rate\nEngagement Rate
# 423811  CTR\nConversion Rate\nEngagement Rate
#
#                                                 6           7           8   \
# 0       320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 1       320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 2       320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 3       320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 4       320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# ...                                            ...         ...         ...
# 423807  320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 423808  320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 423809  320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 423810  320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
# 423811  320x480 (Fullscreen mobile / interstitial)  01/10/2020  31/12/2020
#
#                               9   ... 30      31                          32  \
# 0       Dealership List provided  ...  6  Mobile                      Chrome
# 1       Dealership List provided  ...  6  Mobile               Mobile Safari
# 2       Dealership List provided  ...  6  Mobile  Mobile Safari UI/WKWebView
# 3       Dealership List provided  ...  6  Mobile                      Chrome
# 4       Dealership List provided  ...  6  Mobile               Chrome Mobile
# ...                          ...  ... ..     ...                         ...
# 423807  Dealership List provided  ...  6  Mobile                      Chrome
# 423808  Dealership List provided  ...  6  Mobile  Mobile Safari UI/WKWebView
# 423809  Dealership List provided  ...  6  Mobile                      Chrome
# 423810  Dealership List provided  ...  6  Mobile               Chrome Mobile
# 423811  Dealership List provided  ...  6  Mobile               Chrome Mobile
#
#           33    34    35  36    37    38  39
# 0       None  None  None NaN  None  None NaN
# 1       None  None  None NaN  None  None NaN
# 2       None  None  None NaN  None  None NaN
# 3       None  None  None NaN  None  None NaN
# 4       None  None  None NaN  None  None NaN
# ...      ...   ...   ...  ..   ...   ...  ..
# 423807  None  None  None NaN  None  None NaN
# 423808  None  None  None NaN  None  None NaN
# 423809  None  None  None NaN  None  None NaN
# 423810  None  None  None NaN  None  None NaN
# 423811  None  None  None NaN  None  None NaN
#
# [423812 rows x 40 columns]

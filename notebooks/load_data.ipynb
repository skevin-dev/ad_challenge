# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))
from scripts.postgres import PostgresDBUtils

# %%
pgu = PostgresDBUtils()

# %%
df = pgu.db_execute_fetch(table_name='all_data')
# Out:
# 423812 records fetched from all_data table

# %%
df.head()
# Out:
#   campaign_id                                      campaign_name  \
# 0     qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 1     qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 2     qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 3     qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
# 4     qccvyu0  Yamaha | Wolverine RMAX 1000 | Sensory User Ch...
#
#     submission_date                                        description  \
# 0  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 1  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 2  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 3  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
# 4  23/09/2020 22:00  Hey Kentaro - Below is the info for the Yamaha...
#
#                                  campaign_objectives  \
# 0  Brand Awareness\nProduct Awareness\nConsiderat...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423812 entries, 0 to 423811
# Data columns (total 40 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   campaign_id                         422828 non-null  object
#  1   campaign_name                       422828 non-null  object
#  2   submission_date                     422828 non-null  object
#  3   description                         422828 non-null  object
#  4   campaign_objectives                 422828 non-null  object
#  5   kpis                                422828 non-null  object
#  6   placements                          422828 non-null  object
#  7   start_date                          422828 non-null  object
#  8   end_date                            422828 non-null  object
#  9   serving_locations                   422828 non-null  object
#  10  black_white_audience_list_included  422828 non-null  object
# ...
